# %% [markdown]
# <a href="https://colab.research.google.com/github/lorenzoppx/Physic/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
####### building #########
 
from sympy import *
import numpy as np
 
t, x, y, z = symbols('t x y z')
 
#Números de matrícula X,Y e Z
matricula=[]
 
print("Digite o número de matrícula:");
matricula=input()
 
if( len(str(matricula)) != 10):
    print("Erro no numero de matrícula!");
 
 
x=int(matricula[7])
y=int(matricula[8])
z=int(matricula[9])
print("\nMatrícula okay! As variáveis  sao: \n\t","X:",x ,"Y:", y ,"Z:",z)
 
 
#funcao calculo questão 1
def Questao_1(x,y,z,Xt,Massa,tempo):
  #diferencia a posição para achar V(t)
  Vt = Xt.diff(t)
  print("Expressao de Vt:",Vt)
 
  #substitui t na expressão de V(t)
  Vt_num = Vt.subs(t,tempo)
  print("Resposta numérica de Vt:", Vt_num)
 
  print("Resposta numérica de Massa:", Massa)
 
  #calcula a energia cinética
  Ec=(Massa*(Vt_num**2))/2
  print("Resposta numérica da Energia cinética:", Ec)
 
#funcao calculo questão 1
def Questao_2(x,y,z,Xt,Massa,Raio,tempo):
  #diferencia a posição para achar V(t)
  Vt = Xt.diff(t)
  print("Expressao de Vt:",Vt)
 
  #substitui t na expressão de V(t)
  Vt_num = Vt.subs(t,tempo)
  print("Resposta numérica de Vt:", Vt_num)
 
  print("Resposta numérica de Massa:", Massa)
 
  #calcula a energia cinética
  Fc=(Massa*(Vt_num**2))/Raio
  print("Resposta numérica da Força centrípeta:", Fc)
 
 
print("\n\t--------- Questao 1 ---------\n")
 
 
print("\n--- Item A")
#valor do tempo
tempo=0.4
#expressao da posicao X(t) letra A
Xt = ( (2 + x/3 + z)*t**5 ) + ( (2 + y/2 + z)*t**3 ) + ( (4 + z/4 + x)*t**2 )
#expressao da massa
Massa=((10+x)/3)
#funcao calcula Questao 1
Questao_1(x,y,z,Xt,Massa,tempo)
print("\n")
 
print("\n--- Item B")
#valor do tempo
tempo=0.6
#expressao da posicao X(t) letra B
Xt= ( (4 + x/3 + y )*t**6 ) + ( (5 + y/6 + x)*t**4 ) + ( (5 + z/6 + x)*t**3 )
#expressao da massa
Massa=((20+y)/4)
#funcao calcula Questao 1
Questao_1(x,y,z,Xt,Massa,tempo)
print("\n")
 
print("\n--- Item C")
#valor do tempo
tempo=0.7
#expressao da posicao X(t) letra B
Xt = ( (5 + x/x)*t**6 ) + ( (7 + y/x)*t**4 ) + ( (7 + z/x)*t**3 )
#expressao da massa
Massa=((30+z)/5)
#funcao calcula Questao 1
Questao_1(x,y,z,Xt,Massa,tempo)
print("\n")
 
print("\n--- Item D")
#valor do tempo
tempo=0.8
#expressao da posicao X(t) letra B
Xt = ( (6 + x/2)*t**7 ) + ( (9 + y/2)*t**5 ) + ( (9 + z/2)*t**4 )
#expressao da massa
Massa=((40+y+z)/6)
#funcao calcula Questao 1
Questao_1(x,y,z,Xt,Massa,tempo)
print("\n")


print("\n\t------ Questão 4 ------\n")

print("\n--- Item A")
#valor do tempo
tempo=0.2
#expressao da posicao X(t) letra A
Xt = ( ( 2*(2+x) )*t**5 ) + ( ( 4*(3+y) )*t**4 ) + ( ( 6*(4+z) )*t**3) 
#expressao da massa
Massa= (2+x) + (3+y) + (z) 
#expressao do raio
Raio=( (2+x) + (3+z) )
#funcao calcula Questao 1
Questao_2(x,y,z,Xt,Massa,Raio,tempo)
print("\n")

print("\n--- Item B")
#valor do tempo
tempo=0.3
#expressao da posicao X(t) letra A
Xt =  ( ( 3*(5+x) )*t**4 ) + ( ( 5*(6+y) )*t**3) +  (6)*t**2
#expressao da massa
Massa = (3+x) + y 
#expressao do raio
Raio = (2+x) + z 
#funcao calcula Questao 1
Questao_2(x,y,z,Xt,Massa,Raio,tempo)
print("\n")

print("\n--- Item C")
#valor do tempo
tempo=0.4
#expressao da posicao X(t) letra A
Xt =  (6 + x + z)*t**3 + (7 + y + x)*t**4 + 5*(8 + z)*t**5
#expressao da massa
Massa = 10 + y + z 
#expressao do raio
Raio = x + 3*z
#funcao calcula Questao 1
Questao_2(x,y,z,Xt,Massa,Raio,tempo)
print("\n")

print("\n--- Item D")
#valor do tempo
tempo=0.5
#expressao da posicao X(t) letra A
Xt =  (7 + x + y)*t**4 + (8 + y + x)*t**3 + 3*(9 + z)*t**2
#expressao da massa
Massa = x + 20 + z
#expressao do raio
Raio = 4 + y + z
#funcao calcula Questao 1
Questao_2(x,y,z,Xt,Massa,Raio,tempo)
print("\n")
# Out:
# Digite o número de matrícula:
# 2020101577
#
# Matrícula okay! As variáveis  sao:
# 	 X: 5 Y: 7 Z: 7
#
# 	---------Questao 1:---------
#
#
# --- Item A
# Expressao de Vt: 53.3333333333333*t**4 + 37.5*t**2 + 21.5*t
# Resposta numérica de Vt: 15.9653333333333
# Resposta numérica de Massa: 5.0
# Resposta numérica da Energia cinética: 637.229671111111
#
#
#
# --- Item B
# Expressao de Vt: 76.0*t**5 + 44.6666666666667*t**3 + 33.5*t**2
# Resposta numérica de Vt: 27.6177600000000
# Resposta numérica de Massa: 6.75
# Resposta numérica da Energia cinética: 2574.24975253440
#
#
#
# --- Item C
# Expressao de Vt: 36.0*t**5 + 33.6*t**3 + 25.2*t**2
# Resposta numérica de Vt: 29.9233200000000
# Resposta numérica de Massa: 7.4
# Resposta numérica da Energia cinética: 3312.99879534288
#
#
#
# --- Item D
# Expressao de Vt: 59.5*t**6 + 62.5*t**4 + 50.0*t**3
# Resposta numérica de Vt: 66.7975680000000
# Resposta numérica de Massa: 9.0
# Resposta numérica da Energia cinética: 20078.6179082158
#
#
#
# ...
